# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav20004/NLP/blob/main/TFIDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
print("working")
# Out:
# working
